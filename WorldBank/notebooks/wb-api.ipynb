# %%
# %run ../scripts/wb-api.py
# Out:
# Data retrieved successfully!
#             Indicator   Country CountryISO3  Date         Value
# 0   GDP (current US$)  Botswana         BWA  2022  2.032196e+10
# 1   GDP (current US$)  Botswana         BWA  2021  1.875095e+10
# 2   GDP (current US$)  Botswana         BWA  2020  1.496029e+10
# 3   GDP (current US$)  Botswana         BWA  2019  1.672591e+10
# 4   GDP (current US$)  Botswana         BWA  2018  1.703194e+10
# ..                ...       ...         ...   ...           ...
# 61  GDP (current US$)   Lesotho         LSO  1994  8.782509e+08
# 62  GDP (current US$)   Lesotho         LSO  1993  8.355821e+08
# 63  GDP (current US$)   Lesotho         LSO  1992  8.310299e+08
# 64  GDP (current US$)   Lesotho         LSO  1991  7.043254e+08
# 65  GDP (current US$)   Lesotho         LSO  1990  5.964103e+08
#
# [66 rows x 5 columns]

# %%
data = wb.get_data(
    country="lso;bwa;nam;zaf;swz", 
    indicator="NY.GDP.MKTP.CD", 
    start="1990", 
    end="2022"
    )

# Print the parsed data


if data is not None:
    data
data
# Out:
# Data retrieved successfully!
#             Indicator   Country CountryISO3  Date         Value
# 0   GDP (current US$)  Botswana         BWA  2022  2.032196e+10
# 1   GDP (current US$)  Botswana         BWA  2021  1.875095e+10
# 2   GDP (current US$)  Botswana         BWA  2020  1.496029e+10
# 3   GDP (current US$)  Botswana         BWA  2019  1.672591e+10
# 4   GDP (current US$)  Botswana         BWA  2018  1.703194e+10
# ..                ...       ...         ...   ...           ...
# 95  GDP (current US$)   Namibia         NAM  1993  3.251189e+09
# 96  GDP (current US$)   Namibia         NAM  1992  3.429522e+09
# 97  GDP (current US$)   Namibia         NAM  1991  2.996869e+09
# 98  GDP (current US$)   Namibia         NAM  1990  2.789922e+09
# 99  GDP (current US$)  Eswatini         SWZ  2022  4.695373e+09
#
# [100 rows x 5 columns]

# %%
data = wb.get_data(
    country="LSO;BWA",            # Lesotho and Botswana
    indicator="NY.GDP.MKTP.CD",   # GDP (current US$)
    start=1990, 
    end=2022
)

if data is not None:
    print(data)
    
    
data
# Out:
# Data retrieved successfully!
#             Indicator   Country CountryISO3  Date         Value
# 0   GDP (current US$)  Botswana         BWA  2022  2.032196e+10
# 1   GDP (current US$)  Botswana         BWA  2021  1.875095e+10
# 2   GDP (current US$)  Botswana         BWA  2020  1.496029e+10
# 3   GDP (current US$)  Botswana         BWA  2019  1.672591e+10
# 4   GDP (current US$)  Botswana         BWA  2018  1.703194e+10
# ..                ...       ...         ...   ...           ...
# 61  GDP (current US$)   Lesotho         LSO  1994  8.782509e+08
# 62  GDP (current US$)   Lesotho         LSO  1993  8.355821e+08
# 63  GDP (current US$)   Lesotho         LSO  1992  8.310299e+08
# 64  GDP (current US$)   Lesotho         LSO  1991  7.043254e+08
# 65  GDP (current US$)   Lesotho         LSO  1990  5.964103e+08
#
# [66 rows x 5 columns]
#             Indicator   Country CountryISO3  Date         Value
# 0   GDP (current US$)  Botswana         BWA  2022  2.032196e+10
# 1   GDP (current US$)  Botswana         BWA  2021  1.875095e+10
# 2   GDP (current US$)  Botswana         BWA  2020  1.496029e+10
# 3   GDP (current US$)  Botswana         BWA  2019  1.672591e+10
# 4   GDP (current US$)  Botswana         BWA  2018  1.703194e+10
# ..                ...       ...         ...   ...           ...
# 61  GDP (current US$)   Lesotho         LSO  1994  8.782509e+08
# 62  GDP (current US$)   Lesotho         LSO  1993  8.355821e+08
# 63  GDP (current US$)   Lesotho         LSO  1992  8.310299e+08
# 64  GDP (current US$)   Lesotho         LSO  1991  7.043254e+08
# 65  GDP (current US$)   Lesotho         LSO  1990  5.964103e+08
#
# [66 rows x 5 columns]

# %%
# %run ../scripts/wb_api.py

# %%
data1 = wb.get_data(
    country="lso;bra", 
    indicator="NY.GDP.MKTP.CD", 
    start=1990, 
    end=2020, 
    format = "json"
    )

data1
# Out:
# Data retrieved successfully!
#             Indicator  Country CountryISO3  Date         Value
# 0   GDP (current US$)   Brazil         BRA  2020  1.476107e+12
# 1   GDP (current US$)   Brazil         BRA  2019  1.873288e+12
# 2   GDP (current US$)   Brazil         BRA  2018  1.916934e+12
# 3   GDP (current US$)   Brazil         BRA  2017  2.063515e+12
# 4   GDP (current US$)   Brazil         BRA  2016  1.795693e+12
# ..                ...      ...         ...   ...           ...
# 57  GDP (current US$)  Lesotho         LSO  1994  8.782509e+08
# 58  GDP (current US$)  Lesotho         LSO  1993  8.355821e+08
# 59  GDP (current US$)  Lesotho         LSO  1992  8.310299e+08
# 60  GDP (current US$)  Lesotho         LSO  1991  7.043254e+08
# 61  GDP (current US$)  Lesotho         LSO  1990  5.964103e+08
#
# [62 rows x 5 columns]
