# %%
# %run ../scripts/wb-api1.py

# %%
data = wbpy.get_data(country="lso;bwa;nam;zaf;swz", indicator="NY.GDP.MKTP.CD", start="1990", end="2022")

# Print the parsed data
print("Parsed data:", data)
# Out:
# Raw response text: ï»¿<?xml version="1.0" encoding="utf-8"?>
# <wb:data page="1" pages="4" per_page="50" total="165" sourceid="2" lastupdated="2024-10-24" xmlns:wb="http://www.worldbank.org">
#   <wb:data>
#     <wb:indicator id="NY.GDP.MKTP.CD">GDP (current US$)</wb:indicator>
#     <wb:country id="BW">Botswana</wb:country>
#     <wb:countryiso3code>BWA</wb:countryiso3code>
#     <wb:date>2022</wb:date>
#     <wb:value>20321958850.0363</wb:value>
#     <wb:unit />
#     <wb:obs_status />
#     <wb:decimal>0</wb:decimal>
#   </wb:data>
#   <wb:data>
#     <wb:indicator id="NY.GDP.MKTP.CD">GDP (current US$)</wb:indicator>
#     <wb:country id="BW">Botswana</wb:country>
#     <wb:countryiso3code>BWA</wb:countryiso3code>
#     <wb:date>2021</wb:date>
#     <wb:value>18750946600.1423</wb:value>
#     <wb:unit />
#     <wb:obs_status />
#     <wb:decimal>0</wb:decimal>
#   </wb:data>
#   <wb:data>
#     <wb:indicator id="NY.GDP.MKTP.CD">GDP (current US$)</wb:indicator>
# ...
